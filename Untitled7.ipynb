# %% [markdown]
# <a href="https://colab.research.google.com/github/Danilocerna18/Intro_datos/blob/Prelab0/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prelab lab0

# %% [markdown]
# ## 1. Investigación sobre Jupyter Notebooks

# %% [markdown]
# **Jupyter Notebook** es una aplicación web interactiva que permite escribir y ejecutar código Python desde el navegador.
#
# **Google Colab**
# Colab es un servicio alojado de Jupyter Notebook que no requiere configuración y que ofrece acceso sin coste económico a recursos de computación, como GPUs y TPUs. Colab es una solución especialmente adecuada para el aprendizaje automático, la ciencia de datos y la educación.
#
# es una plataforma basada en Jupyter Notebook que funciona en la nube y permite trabajar sin instalar programas.
#
# **Características**
#
# Ejecutar código por celdas.
#
# Combinar texto, imágenes y código.
#
# Crear gráficas y tablas.
#
# Guardado automático.
#
# Compartir notebooks fácilmente.
#
# Uso de GPU y TPU gratis en Colab.
#
# **Ventajas**
#
# Fácil de usar.
#
# Ideal para análisis de datos.
#
# Muy utilizado en universidades y empresas.
#
# Permite documentar procedimientos paso a paso.
#
# Desventajas
#
# No es ideal para proyectos muy grandes.
#
# Puede consumir bastante memoria.
#
# El orden de ejecución puede causar errores.
#
# https://research.google.com/colaboratory/intl/es/faq.html#:~:text=Colab%20es%20un%20servicio%20alojado,de%20datos%20y%20la%20educaci%C3%B3n.&text=S%C3%AD.

# %% [markdown]
# ## 2. Investigación sobre librerías nativas de Python para manejo de archivos

# %% [markdown]
# Manejo de archivos TXT
#
# Se utiliza la función open().
#
# Modos de apertura:
#
# "r" → leer
#
# "w" → escribir
#
# "a" → agregar contenido
#
# "x" → crear archivo
#
# "b" → modo binario

# %% [markdown]
# **La librería csv **permite trabajar con archivos separados por comas.
#
# **La librería json **permite manejar datos en formato JSON.
#
# **La librería os** sirve para interactuar con el sistema operativo.
#
# **Librería Pickle** permite guardar objetos Python en archivos binarios.
#
# El manejo de archivos permite:
#
# Guardar información.
# Leer bases de datos.
# Automatizar procesos.
# Intercambiar datos entre sistemas.
#
# https://www.datacamp.com/es/blog/top-python-libraries-for-data-science

# %% [markdown]
# ## Investigar librería de Numpy

# %% [markdown]
# NumPy es un proyecto de código abierto cuyo objetivo es permitir la computación numérica en Python. Fue creado en el 2005, a partir de los primeros trabajos de las bibliotecas Numeric y Numarray. NumPy siempre será un software 100% de código abierto y de uso libre para todos.
#
# NumPy es una librería de Python especializada en el cálculo numérico y el análisis de datos, especialmente para un gran volumen de datos.
#
# **Características**
#
# Manejo de arreglos multidimensionales.
#
# Operaciones matemáticas rápidas.
#
# Alto rendimiento.
#
# Base para librerías como Pandas y TensorFlow.
#
#
# https://aprendeconalf.es/docencia/python/manual/numpy/#:~:text=NumPy%20es%20una%20librer%C3%ADa%20de,un%20gran%20volumen%20de%20datos.
#
#
# https://numpy.org/es/about/#:~:text=NumPy%20es%20un%20proyecto%20de,de%20uso%20libre%20para%20todos.

# %% [markdown]
# ## Investigar librería de Pandas

# %% [markdown]
# Pandas es una biblioteca para Ciencia de Datos de código abierto (open source), construida sobre el lenguaje Python, y que proporciona un enfoque rápido y flexible, con estructuras robustas para trabajar con datos relacionales (o etiquetados), y todo eso de manera sencilla y intuitiva.
#
#
# Las principales características de esta librería son:
#
# Define nuevas estructuras de datos basadas en los arrays de la librería NumPy pero con nuevas funcionalidades.
# Permite leer y escribir fácilmente ficheros en formato CSV, Excel y bases de datos SQL.
# Permite acceder a los datos mediante índices o nombres para filas y columnas.
# Ofrece métodos para reordenar, dividir y combinar conjuntos de datos.
# Permite trabajar con series temporales.
# Realiza todas estas operaciones de manera muy eficiente.
#
#
# https://aprendeconalf.es/docencia/python/manual/pandas/
#
# https://www.aluracursos.com/blog/pandas-python-que-es-para-que-sirve-como-descargar
